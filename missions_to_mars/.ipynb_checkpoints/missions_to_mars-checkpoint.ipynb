# %% [markdown]
# # Import Dependencies and the required modules

# %%
# Dependencies
import pandas as pd
import pdb

# Import BeautifulSoup
from bs4 import BeautifulSoup as bs
import requests

# Import Splinter and set the chromedriver path
from splinter import Browser
from selenium import webdriver

# Module used to connect Python with MongoDb
import pymongo

# %% [markdown]
# # NASA Mars News

# %%
# Scrape the NASA Mars News Site and collect the latest News Title and Paragraph Text. 
# Assign the text to variables that you can reference later.

# URL of page to be scraped
url_nasa = "https://mars.nasa.gov/news/?page=0&per_page=40&order=publish_date+desc%2Ccreated_at+desc&search=&category=19%2C165%2C184%2C204&blank_scope=Latest"

# executable path and browser
executable_path = {"executable_path": "/usr/local/bin/chromedriver"}
browser = Browser("chrome", **executable_path, headless=False)
browser.visit(url_nasa)

# Retrieve page with the requested module
#response = requests.get(url_nasa)

# Create Beatifulsoup object; pase with 'html.parser' or 'lxml'
soup = bs(browser.html, 'html.parser')

# Examine the results, then determine element that contains the info needed
#print(soup.prettify()) #Note: it was very useful to print the first time, afterwards it is impractical.

# %%
# Scrape the NASA Mars News Site and collect the latest News Title and Paragraph Text. 
# Assign the text to variables that you can reference later.
# Results are returned as an iterable list
nasa_news_results = soup.find_all('li', class_='slide')  
#print(nasa_news_results)

# %%
# The default port used by MongoDB is 27017
# https://docs.mongodb.com/manual/reference/default-mongodb-port/
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Define database and collection
db = client.nasaNews_db
collection = db.items

# Retrieve page with the requests module
response = requests.get(url_nasa)

# %%
# Loop through returned results
for result in nasa_news_results:
    try:
        nasa_news = result.find('div', class_= 'image_and_description_container')
        date = nasa_news.find('div', class_='list_date').text
        title = result.find('div', class_='content_title').text
        paragraph = nasa_news.find('div', class_='article_teaser_body').text
        
        if (date and title and paragraph):
            print('------------------------')
            print(date)
            print(title)
            print(paragraph)
            
             # Dictionary to be inserted as a MongoDB document
            post = {
                'date': date,
                'title': title,
                'paragraph': paragraph
            }

            collection.insert_one(post)
              
    except AttributeError as e:
        print(e)
# Out:
# ------------------------
# March  5, 2020
# Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover
# NASA chose a seventh-grader from Virginia as winner of the agency's "Name the Rover" essay contest. Alexander Mather's entry for "Perseverance" was voted tops among 28,000 entries.
# ------------------------
# March  4, 2020
# NASA's Curiosity Mars Rover Snaps Its Highest-Resolution Panorama Yet
# To go along with the stunning 1.8-billion-pixel image, a new video offers a sweeping view of the Red Planet.
# ------------------------
# March  3, 2020
# NASA to Reveal Name of Its Next Mars Rover
# After a months-long contest among students to name NASA's newest Mars rover, the agency will reveal the winning name — and the winning student — this Thursday.
# ------------------------
# February 27, 2020
# The MarCO Mission Comes to an End
# The pair of briefcase-sized satellites made history when they sailed past Mars in 2019.
# ------------------------
# February 24, 2020
# A Year of Surprising Science From NASA's InSight Mars Mission
# A batch of new papers summarizes the lander's findings above and below the surface of the Red Planet.
# ------------------------
# February 21, 2020
# Mars InSight Lander to Push on Top of the 'Mole'
# Engineers have a plan for pushing down on the heat probe, which has been stuck at the Martian surface for a year.
# ------------------------
# February 21, 2020
# Common Questions about InSight's 'Mole'
# The following Q&As with members of the team answer some of the most common questions about the burrowing device, part of a science instrument called the Heat Flow and Physical Properties Package (HP3).
# ------------------------
# February 20, 2020
# NASA Adds Return Sample Scientists to Mars 2020 Leadership Team
# The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.
# ------------------------
# February 18, 2020
# NASA's Mars Reconnaissance Orbiter Undergoes Memory Update
# Other orbiters will continue relaying data from Mars surface missions for a two-week period.
# ------------------------
# February 12, 2020
# NASA's Mars 2020 Rover Goes Coast-to-Coast to Prep for Launch
# The agency's first step in returning rocks from Mars just arrived at Kennedy Space Center. The Mars 2020 team now begins readying for a launch to the Red Planet this July.
# ------------------------
# February 11, 2020
# NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network
# Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.
# ------------------------
# February 10, 2020
# NASA Administrator Statement on Moon to Mars Initiative, FY 2021 Budget
# Jim Bridenstine addresses NASA's ambitious plans for the coming years, including Mars Sample Return.
# ------------------------
# February  7, 2020
# All About the Laser (and Microphone) Atop Mars 2020, NASA's Next Rover
# SuperCam is a rock-vaporizing instrument that will help scientists hunt for Mars fossils.
# ------------------------
# February  3, 2020
# NASA's MAVEN Explores Mars to Understand Radio Interference at Earth
# NASA’s MAVEN spacecraft has discovered “layers” and “rifts” in the electrically charged part of the upper atmosphere of Mars.
# ------------------------
# January 21, 2020
# Nine Finalists Chosen in NASA's Mars 2020 Rover Naming Contest
# Nine finalists have been chosen in the essay contest for K-12 students across U.S. to name NASA's next Mars rover. Now you can help by voting for your favorite.
# ------------------------
# January 13, 2020
# NASA's Mars 2020 Rover Closer to Getting Its Name
# 155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July.
# ------------------------
# December 27, 2019
# Media Get a Close-Up of NASA's Mars 2020 Rover
# The clean room at NASA's Jet Propulsion Laboratory was open to the media to see NASA's next Mars explorer before it leaves for Florida in preparation for a summertime launch.
# ------------------------
# December 23, 2019
# Space History Is Made in This NASA Robot Factory
# From rockets to rovers, JPL's Spacecraft Assembly Facility has been at the center of robotic spaceflight. Here's a closer look at what makes it so special.
# ------------------------
# December 18, 2019
# NASA's Mars 2020 Rover Completes Its First Drive
# In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.
# ------------------------
# December 12, 2019
# NASA's MAVEN Maps Winds in the Martian Upper Atmosphere that Mirror the Terrain Below and Gives Clues to Martian Climate
# Researchers have created the first map of wind circulation in the upper atmosphere of a planet besides Earth, using data from NASA’s MAVEN spacecraft that were collected during the last two years.
# ------------------------
# December 12, 2019
# Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate
# A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.
# ------------------------
# December 10, 2019
# NASA's Treasure Map for Water Ice on Mars
# A new study identifies frozen water just below the Martian surface, where astronauts could easily dig it up.
# ------------------------
# December 10, 2019
# Two Rovers to Roll on Mars Again: Curiosity and Mars 2020
# They look like twins. But under the hood, the rover currently exploring the Red Planet and the one launching there this summer have distinct science tools and roles to play.
# ------------------------
# November 27, 2019
# NASA's Briefcase-Size MarCO Satellite Picks Up Honors
# The twin spacecraft, the first of their kind to fly into deep space, earn a Laureate from Aviation Week & Space Technology.
# ------------------------
# November 26, 2019
# Global Storms on Mars Launch Dust Towers Into the Sky
# A Mars Dust Tower Stands Out Dust storms are common on Mars. But every decade or so, something unpredictable happens: a series of runaway storms break out, covering the entire planet in a dusty haze.
# ------------------------
# November 21, 2019
# NASA Updates Mars 2020 Mission Environmental Review
# NASA and the Department of Energy have completed a more detailed risk analysis for the Mars 2020 rover launch from Florida.
# ------------------------
# November 20, 2019
# Two of a Space Kind: Apollo 12 and Mars 2020
# Apollo 12 and the upcoming Mars 2020 mission may be separated by half a century, but they share several goals unique in the annals of space exploration.
# ------------------------
# November 15, 2019
# Mars Scientists Investigate Ancient Life in Australia
# Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions.
# ------------------------
# November 12, 2019
# NASA's Mars 2020 Will Hunt for Microscopic Fossils
# A new paper identifies a ring of minerals at the rover's landing site that are ideal for fossilizing microbial life.
# ------------------------
# November 12, 2019
# With Mars Methane Mystery Unsolved, Curiosity Serves Scientists a New One: Oxygen
# For the first time in the history of space exploration, scientists have measured the seasonal changes in the gases that fill the air directly above the surface of Gale Crater on Mars.
# ------------------------
# November  7, 2019
# NASA's Mars 2020 Heads Into the Test Chamber
# In this time-lapse video taken at JPL, engineers move the Mars 2020 rover into a large vacuum chamber for testing in Mars-like environmental conditions.
# ------------------------
# November  7, 2019
# Screening Soon: 'The Pathfinders' Trains Lens on Mars
# With the Mars 2020 mission ramping up, the documentary — the first of four about past JPL missions to the Red Planet to be shown at Caltech — tells a gripping backstory.
# ------------------------
# November  6, 2019
# InSight's 'Mole' Team Peers into the Pit
# Efforts to save the heat probe continue.
# ------------------------
# October 24, 2019
# Mars 2020 Stands on Its Own Six Wheels
# In time-lapse video, taken at JPL, captures the first time NASA's Mars 2020 rover carries its full weight on its legs and wheels.
# ------------------------
# October 24, 2019
# New Selfie Shows Curiosity, the Mars Chemist
# The NASA rover performed a special chemistry experiment at the location captured in its newest self-portrait.
# ------------------------
# October 22, 2019
# Naming a NASA Mars Rover Can Change Your Life
# Want to name the robotic scientist NASA is sending to Mars in 2020? The student who named Curiosity — the rover currently exploring Mars — will tell you this is an opportunity worth taking.
# ------------------------
# October 18, 2019
# Mars 2020 Unwrapped and Ready for More Testing
# In time-lapse video, bunny-suited engineers remove the inner layer of protective foil on NASA's Mars 2020 rover after it was relocated for testing.
# ------------------------
# October 16, 2019
# HiRISE Views NASA's InSight and Curiosity on Mars
# New images taken from space offer the clearest orbital glimpse yet of InSight as well as a view of Curiosity rolling along.
# ------------------------
# October  7, 2019
# NASA's Curiosity Rover Finds an Ancient Oasis on Mars
# New evidence suggests salty, shallow ponds once dotted a Martian crater — a sign of the planet's drying climate.
# ------------------------
# October  4, 2019
# NASA's Mars 2020 Rover Tests Descent-Stage Separation
# A crane lifts the rocket-powered descent stage away from NASA's Mars 2020 rover after technicians tested the pyrotechnic charges that separate the two spacecraft.

# %%
# Display items in MongoDB collection
listings = db.items.find()

for listing in listings:
    print(listing)
# Out:
# {'_id': ObjectId('5e6dab6c9c1c6d1d199519cf'), 'date': 'March  5, 2020', 'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover", 'paragraph': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '}
# {'_id': ObjectId('5e6dab6c9c1c6d1d199519d0'), 'date': 'March  4, 2020', 'title': "NASA's Curiosity Mars Rover Snaps Its Highest-Resolution Panorama Yet", 'paragraph': 'To go along with the stunning 1.8-billion-pixel image, a new video offers a sweeping view of the Red Planet.'}
# {'_id': ObjectId('5e6dab6c9c1c6d1d199519d1'), 'date': 'March  3, 2020', 'title': 'NASA to Reveal Name of Its Next Mars Rover', 'paragraph': "After a months-long contest among students to name NASA's newest Mars rover, the agency will reveal the winning name — and the winning student — this Thursday. "}
# {'_id': ObjectId('5e6dab6c9c1c6d1d199519d2'), 'date': 'February 27, 2020', 'title': 'The MarCO Mission Comes to an End', 'paragraph': 'The pair of briefcase-sized satellites made history when they sailed past Mars in 2019.'}
# {'_id': ObjectId('5e6dab6c9c1c6d1d199519d3'), 'date': 'February 24, 2020', 'title': "A Year of Surprising Science From NASA's InSight Mars Mission", 'paragraph': "A batch of new papers summarizes the lander's findings above and below the surface of the Red Planet."}
# {'_id': ObjectId('5e6dab6c9c1c6d1d199519d4'), 'date': 'February 21, 2020', 'title': "Mars InSight Lander to Push on Top of the 'Mole'", 'paragraph': 'Engineers have a plan for pushing down on the heat probe, which has been stuck at the Martian surface for a year.'}
# {'_id': ObjectId('5e6dab6c9c1c6d1d199519d5'), 'date': 'February 21, 2020', 'title': "Common Questions about InSight's 'Mole'", 'paragraph': 'The following Q&As with members of the team answer some of the most common questions about the burrowing device, part of a science instrument called the Heat Flow and Physical Properties Package (HP3).'}
# {'_id': ObjectId('5e6dab6c9c1c6d1d199519d6'), 'date': 'February 20, 2020', 'title': 'NASA Adds Return Sample Scientists to Mars 2020 Leadership Team', 'paragraph': 'The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.'}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519d7'), 'date': 'February 18, 2020', 'title': "NASA's Mars Reconnaissance Orbiter Undergoes Memory Update", 'paragraph': 'Other orbiters will continue relaying data from Mars surface missions for a two-week period.'}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519d8'), 'date': 'February 12, 2020', 'title': "NASA's Mars 2020 Rover Goes Coast-to-Coast to Prep for Launch", 'paragraph': "The agency's first step in returning rocks from Mars just arrived at Kennedy Space Center. The Mars 2020 team now begins readying for a launch to the Red Planet this July."}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519d9'), 'date': 'February 11, 2020', 'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network', 'paragraph': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519da'), 'date': 'February 10, 2020', 'title': 'NASA Administrator Statement on Moon to Mars Initiative, FY 2021 Budget', 'paragraph': "Jim Bridenstine addresses NASA's ambitious plans for the coming years, including Mars Sample Return."}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519db'), 'date': 'February  7, 2020', 'title': "All About the Laser (and Microphone) Atop Mars 2020, NASA's Next Rover", 'paragraph': 'SuperCam is a rock-vaporizing instrument that will help scientists hunt for Mars fossils.'}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519dc'), 'date': 'February  3, 2020', 'title': "NASA's MAVEN Explores Mars to Understand Radio Interference at Earth", 'paragraph': 'NASA’s MAVEN spacecraft has discovered “layers” and “rifts” in the electrically charged part of the upper atmosphere of Mars.'}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519dd'), 'date': 'January 21, 2020', 'title': "Nine Finalists Chosen in NASA's Mars 2020 Rover Naming Contest", 'paragraph': "Nine finalists have been chosen in the essay contest for K-12 students across U.S. to name NASA's next Mars rover. Now you can help by voting for your favorite. "}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519de'), 'date': 'January 13, 2020', 'title': "NASA's Mars 2020 Rover Closer to Getting Its Name", 'paragraph': "155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July."}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519df'), 'date': 'December 27, 2019', 'title': "Media Get a Close-Up of NASA's Mars 2020 Rover", 'paragraph': "The clean room at NASA's Jet Propulsion Laboratory was open to the media to see NASA's next Mars explorer before it leaves for Florida in preparation for a summertime launch."}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519e0'), 'date': 'December 23, 2019', 'title': 'Space History Is Made in This NASA Robot Factory', 'paragraph': "From rockets to rovers, JPL's Spacecraft Assembly Facility has been at the center of robotic spaceflight. Here's a closer look at what makes it so special."}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519e1'), 'date': 'December 18, 2019', 'title': "NASA's Mars 2020 Rover Completes Its First Drive", 'paragraph': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519e2'), 'date': 'December 12, 2019', 'title': "NASA's MAVEN Maps Winds in the Martian Upper Atmosphere that Mirror the Terrain Below and Gives Clues to Martian Climate", 'paragraph': 'Researchers have created the first map of wind circulation in the upper atmosphere of a planet besides Earth, using data from NASA’s MAVEN spacecraft that were collected during the last two years.'}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519e3'), 'date': 'December 12, 2019', 'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate", 'paragraph': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519e4'), 'date': 'December 10, 2019', 'title': "NASA's Treasure Map for Water Ice on Mars", 'paragraph': 'A new study identifies frozen water just below the Martian surface, where astronauts could easily dig it up.'}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519e5'), 'date': 'December 10, 2019', 'title': 'Two Rovers to Roll on Mars Again: Curiosity and Mars 2020', 'paragraph': 'They look like twins. But under the hood, the rover currently exploring the Red Planet and the one launching there this summer have distinct science tools and roles to play.'}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519e6'), 'date': 'November 27, 2019', 'title': "NASA's Briefcase-Size MarCO Satellite Picks Up Honors", 'paragraph': 'The twin spacecraft, the first of their kind to fly into deep space, earn a Laureate from Aviation Week & Space Technology.'}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519e7'), 'date': 'November 26, 2019', 'title': 'Global Storms on Mars Launch Dust Towers Into the Sky', 'paragraph': 'A Mars Dust Tower Stands Out Dust storms are common on Mars. But every decade or so, something unpredictable happens: a series of runaway storms break out, covering the entire planet in a dusty haze.'}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519e8'), 'date': 'November 21, 2019', 'title': 'NASA Updates Mars 2020 Mission Environmental Review', 'paragraph': 'NASA and the Department of Energy have completed a more detailed risk analysis for the Mars 2020 rover launch from Florida.'}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519e9'), 'date': 'November 20, 2019', 'title': 'Two of a Space Kind: Apollo 12 and Mars 2020', 'paragraph': 'Apollo 12 and the upcoming Mars 2020 mission may be separated by half a century, but they share several goals unique in the annals of space exploration.'}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519ea'), 'date': 'November 15, 2019', 'title': 'Mars Scientists Investigate Ancient Life in Australia', 'paragraph': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519eb'), 'date': 'November 12, 2019', 'title': "NASA's Mars 2020 Will Hunt for Microscopic Fossils", 'paragraph': "A new paper identifies a ring of minerals at the rover's landing site that are ideal for fossilizing microbial life."}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519ec'), 'date': 'November 12, 2019', 'title': 'With Mars Methane Mystery Unsolved, Curiosity Serves Scientists a New One: Oxygen', 'paragraph': 'For the first time in the history of space exploration, scientists have measured the seasonal changes in the gases that fill the air directly above the surface of Gale Crater on Mars. '}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519ed'), 'date': 'November  7, 2019', 'title': "NASA's Mars 2020 Heads Into the Test Chamber", 'paragraph': 'In this time-lapse video taken at JPL, engineers move the Mars 2020 rover into a large vacuum chamber for testing in Mars-like environmental conditions.'}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519ee'), 'date': 'November  7, 2019', 'title': "Screening Soon: 'The Pathfinders' Trains Lens on Mars", 'paragraph': 'With the Mars 2020 mission ramping up, the documentary — the first of four about past JPL missions to the Red Planet to be shown at Caltech — tells a gripping backstory.'}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519ef'), 'date': 'November  6, 2019', 'title': "InSight's 'Mole' Team Peers into the Pit", 'paragraph': 'Efforts to save the heat probe continue.'}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519f0'), 'date': 'October 24, 2019', 'title': 'Mars 2020 Stands on Its Own Six Wheels', 'paragraph': "In time-lapse video, taken at JPL, captures the first time NASA's Mars 2020 rover carries its full weight on its legs and wheels."}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519f1'), 'date': 'October 24, 2019', 'title': 'New Selfie Shows Curiosity, the Mars Chemist', 'paragraph': 'The NASA rover performed a special chemistry experiment at the location captured in its newest self-portrait.'}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519f2'), 'date': 'October 22, 2019', 'title': 'Naming a NASA Mars Rover Can Change Your Life', 'paragraph': 'Want to name the robotic scientist NASA is sending to Mars in 2020? The student who named Curiosity — the rover currently exploring Mars — will tell you this is an opportunity worth taking.'}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519f3'), 'date': 'October 18, 2019', 'title': 'Mars 2020 Unwrapped and Ready for More Testing', 'paragraph': "In time-lapse video, bunny-suited engineers remove the inner layer of protective foil on NASA's Mars 2020 rover after it was relocated for testing."}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519f4'), 'date': 'October 16, 2019', 'title': "HiRISE Views NASA's InSight and Curiosity on Mars", 'paragraph': 'New images taken from space offer the clearest orbital glimpse yet of InSight as well as a view of Curiosity rolling along.'}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519f5'), 'date': 'October  7, 2019', 'title': "NASA's Curiosity Rover Finds an Ancient Oasis on Mars", 'paragraph': "New evidence suggests salty, shallow ponds once dotted a Martian crater — a sign of the planet's drying climate."}
# {'_id': ObjectId('5e6dab6d9c1c6d1d199519f6'), 'date': 'October  4, 2019', 'title': "NASA's Mars 2020 Rover Tests Descent-Stage Separation", 'paragraph': "A crane lifts the rocket-powered descent stage away from NASA's Mars 2020 rover after technicians tested the pyrotechnic charges that separate the two spacecraft."}
# {'_id': ObjectId('5e6e94111847df41ffb673ec'), 'date': 'March  5, 2020', 'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover", 'paragraph': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '}
# {'_id': ObjectId('5e6e94111847df41ffb673ed'), 'date': 'March  4, 2020', 'title': "NASA's Curiosity Mars Rover Snaps Its Highest-Resolution Panorama Yet", 'paragraph': 'To go along with the stunning 1.8-billion-pixel image, a new video offers a sweeping view of the Red Planet.'}
# {'_id': ObjectId('5e6e94111847df41ffb673ee'), 'date': 'March  3, 2020', 'title': 'NASA to Reveal Name of Its Next Mars Rover', 'paragraph': "After a months-long contest among students to name NASA's newest Mars rover, the agency will reveal the winning name — and the winning student — this Thursday. "}
# {'_id': ObjectId('5e6e94111847df41ffb673ef'), 'date': 'February 27, 2020', 'title': 'The MarCO Mission Comes to an End', 'paragraph': 'The pair of briefcase-sized satellites made history when they sailed past Mars in 2019.'}
# {'_id': ObjectId('5e6e94111847df41ffb673f0'), 'date': 'February 24, 2020', 'title': "A Year of Surprising Science From NASA's InSight Mars Mission", 'paragraph': "A batch of new papers summarizes the lander's findings above and below the surface of the Red Planet."}
# {'_id': ObjectId('5e6e94111847df41ffb673f1'), 'date': 'February 21, 2020', 'title': "Mars InSight Lander to Push on Top of the 'Mole'", 'paragraph': 'Engineers have a plan for pushing down on the heat probe, which has been stuck at the Martian surface for a year.'}
# {'_id': ObjectId('5e6e94111847df41ffb673f2'), 'date': 'February 21, 2020', 'title': "Common Questions about InSight's 'Mole'", 'paragraph': 'The following Q&As with members of the team answer some of the most common questions about the burrowing device, part of a science instrument called the Heat Flow and Physical Properties Package (HP3).'}
# {'_id': ObjectId('5e6e94111847df41ffb673f3'), 'date': 'February 20, 2020', 'title': 'NASA Adds Return Sample Scientists to Mars 2020 Leadership Team', 'paragraph': 'The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.'}
# {'_id': ObjectId('5e6e94111847df41ffb673f4'), 'date': 'February 18, 2020', 'title': "NASA's Mars Reconnaissance Orbiter Undergoes Memory Update", 'paragraph': 'Other orbiters will continue relaying data from Mars surface missions for a two-week period.'}
# {'_id': ObjectId('5e6e94111847df41ffb673f5'), 'date': 'February 12, 2020', 'title': "NASA's Mars 2020 Rover Goes Coast-to-Coast to Prep for Launch", 'paragraph': "The agency's first step in returning rocks from Mars just arrived at Kennedy Space Center. The Mars 2020 team now begins readying for a launch to the Red Planet this July."}
# {'_id': ObjectId('5e6e94111847df41ffb673f6'), 'date': 'February 11, 2020', 'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network', 'paragraph': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'}
# {'_id': ObjectId('5e6e94111847df41ffb673f7'), 'date': 'February 10, 2020', 'title': 'NASA Administrator Statement on Moon to Mars Initiative, FY 2021 Budget', 'paragraph': "Jim Bridenstine addresses NASA's ambitious plans for the coming years, including Mars Sample Return."}
# {'_id': ObjectId('5e6e94111847df41ffb673f8'), 'date': 'February  7, 2020', 'title': "All About the Laser (and Microphone) Atop Mars 2020, NASA's Next Rover", 'paragraph': 'SuperCam is a rock-vaporizing instrument that will help scientists hunt for Mars fossils.'}
# {'_id': ObjectId('5e6e94111847df41ffb673f9'), 'date': 'February  3, 2020', 'title': "NASA's MAVEN Explores Mars to Understand Radio Interference at Earth", 'paragraph': 'NASA’s MAVEN spacecraft has discovered “layers” and “rifts” in the electrically charged part of the upper atmosphere of Mars.'}
# {'_id': ObjectId('5e6e94111847df41ffb673fa'), 'date': 'January 21, 2020', 'title': "Nine Finalists Chosen in NASA's Mars 2020 Rover Naming Contest", 'paragraph': "Nine finalists have been chosen in the essay contest for K-12 students across U.S. to name NASA's next Mars rover. Now you can help by voting for your favorite. "}
# {'_id': ObjectId('5e6e94111847df41ffb673fb'), 'date': 'January 13, 2020', 'title': "NASA's Mars 2020 Rover Closer to Getting Its Name", 'paragraph': "155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July."}
# {'_id': ObjectId('5e6e94111847df41ffb673fc'), 'date': 'December 27, 2019', 'title': "Media Get a Close-Up of NASA's Mars 2020 Rover", 'paragraph': "The clean room at NASA's Jet Propulsion Laboratory was open to the media to see NASA's next Mars explorer before it leaves for Florida in preparation for a summertime launch."}
# {'_id': ObjectId('5e6e94111847df41ffb673fd'), 'date': 'December 23, 2019', 'title': 'Space History Is Made in This NASA Robot Factory', 'paragraph': "From rockets to rovers, JPL's Spacecraft Assembly Facility has been at the center of robotic spaceflight. Here's a closer look at what makes it so special."}
# {'_id': ObjectId('5e6e94111847df41ffb673fe'), 'date': 'December 18, 2019', 'title': "NASA's Mars 2020 Rover Completes Its First Drive", 'paragraph': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'}
# {'_id': ObjectId('5e6e94111847df41ffb673ff'), 'date': 'December 12, 2019', 'title': "NASA's MAVEN Maps Winds in the Martian Upper Atmosphere that Mirror the Terrain Below and Gives Clues to Martian Climate", 'paragraph': 'Researchers have created the first map of wind circulation in the upper atmosphere of a planet besides Earth, using data from NASA’s MAVEN spacecraft that were collected during the last two years.'}
# {'_id': ObjectId('5e6e94111847df41ffb67400'), 'date': 'December 12, 2019', 'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate", 'paragraph': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'}
# {'_id': ObjectId('5e6e94111847df41ffb67401'), 'date': 'December 10, 2019', 'title': "NASA's Treasure Map for Water Ice on Mars", 'paragraph': 'A new study identifies frozen water just below the Martian surface, where astronauts could easily dig it up.'}
# {'_id': ObjectId('5e6e94111847df41ffb67402'), 'date': 'December 10, 2019', 'title': 'Two Rovers to Roll on Mars Again: Curiosity and Mars 2020', 'paragraph': 'They look like twins. But under the hood, the rover currently exploring the Red Planet and the one launching there this summer have distinct science tools and roles to play.'}
# {'_id': ObjectId('5e6e94111847df41ffb67403'), 'date': 'November 27, 2019', 'title': "NASA's Briefcase-Size MarCO Satellite Picks Up Honors", 'paragraph': 'The twin spacecraft, the first of their kind to fly into deep space, earn a Laureate from Aviation Week & Space Technology.'}
# {'_id': ObjectId('5e6e94111847df41ffb67404'), 'date': 'November 26, 2019', 'title': 'Global Storms on Mars Launch Dust Towers Into the Sky', 'paragraph': 'A Mars Dust Tower Stands Out Dust storms are common on Mars. But every decade or so, something unpredictable happens: a series of runaway storms break out, covering the entire planet in a dusty haze.'}
# {'_id': ObjectId('5e6e94111847df41ffb67405'), 'date': 'November 21, 2019', 'title': 'NASA Updates Mars 2020 Mission Environmental Review', 'paragraph': 'NASA and the Department of Energy have completed a more detailed risk analysis for the Mars 2020 rover launch from Florida.'}
# {'_id': ObjectId('5e6e94111847df41ffb67406'), 'date': 'November 20, 2019', 'title': 'Two of a Space Kind: Apollo 12 and Mars 2020', 'paragraph': 'Apollo 12 and the upcoming Mars 2020 mission may be separated by half a century, but they share several goals unique in the annals of space exploration.'}
# {'_id': ObjectId('5e6e94111847df41ffb67407'), 'date': 'November 15, 2019', 'title': 'Mars Scientists Investigate Ancient Life in Australia', 'paragraph': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "}
# {'_id': ObjectId('5e6e94111847df41ffb67408'), 'date': 'November 12, 2019', 'title': "NASA's Mars 2020 Will Hunt for Microscopic Fossils", 'paragraph': "A new paper identifies a ring of minerals at the rover's landing site that are ideal for fossilizing microbial life."}
# {'_id': ObjectId('5e6e94111847df41ffb67409'), 'date': 'November 12, 2019', 'title': 'With Mars Methane Mystery Unsolved, Curiosity Serves Scientists a New One: Oxygen', 'paragraph': 'For the first time in the history of space exploration, scientists have measured the seasonal changes in the gases that fill the air directly above the surface of Gale Crater on Mars. '}
# {'_id': ObjectId('5e6e94111847df41ffb6740a'), 'date': 'November  7, 2019', 'title': "NASA's Mars 2020 Heads Into the Test Chamber", 'paragraph': 'In this time-lapse video taken at JPL, engineers move the Mars 2020 rover into a large vacuum chamber for testing in Mars-like environmental conditions.'}
# {'_id': ObjectId('5e6e94111847df41ffb6740b'), 'date': 'November  7, 2019', 'title': "Screening Soon: 'The Pathfinders' Trains Lens on Mars", 'paragraph': 'With the Mars 2020 mission ramping up, the documentary — the first of four about past JPL missions to the Red Planet to be shown at Caltech — tells a gripping backstory.'}
# {'_id': ObjectId('5e6e94111847df41ffb6740c'), 'date': 'November  6, 2019', 'title': "InSight's 'Mole' Team Peers into the Pit", 'paragraph': 'Efforts to save the heat probe continue.'}
# {'_id': ObjectId('5e6e94111847df41ffb6740d'), 'date': 'October 24, 2019', 'title': 'Mars 2020 Stands on Its Own Six Wheels', 'paragraph': "In time-lapse video, taken at JPL, captures the first time NASA's Mars 2020 rover carries its full weight on its legs and wheels."}
# {'_id': ObjectId('5e6e94111847df41ffb6740e'), 'date': 'October 24, 2019', 'title': 'New Selfie Shows Curiosity, the Mars Chemist', 'paragraph': 'The NASA rover performed a special chemistry experiment at the location captured in its newest self-portrait.'}
# {'_id': ObjectId('5e6e94111847df41ffb6740f'), 'date': 'October 22, 2019', 'title': 'Naming a NASA Mars Rover Can Change Your Life', 'paragraph': 'Want to name the robotic scientist NASA is sending to Mars in 2020? The student who named Curiosity — the rover currently exploring Mars — will tell you this is an opportunity worth taking.'}
# {'_id': ObjectId('5e6e94111847df41ffb67410'), 'date': 'October 18, 2019', 'title': 'Mars 2020 Unwrapped and Ready for More Testing', 'paragraph': "In time-lapse video, bunny-suited engineers remove the inner layer of protective foil on NASA's Mars 2020 rover after it was relocated for testing."}
# {'_id': ObjectId('5e6e94111847df41ffb67411'), 'date': 'October 16, 2019', 'title': "HiRISE Views NASA's InSight and Curiosity on Mars", 'paragraph': 'New images taken from space offer the clearest orbital glimpse yet of InSight as well as a view of Curiosity rolling along.'}
# {'_id': ObjectId('5e6e94111847df41ffb67412'), 'date': 'October  7, 2019', 'title': "NASA's Curiosity Rover Finds an Ancient Oasis on Mars", 'paragraph': "New evidence suggests salty, shallow ponds once dotted a Martian crater — a sign of the planet's drying climate."}
# {'_id': ObjectId('5e6e94111847df41ffb67413'), 'date': 'October  4, 2019', 'title': "NASA's Mars 2020 Rover Tests Descent-Stage Separation", 'paragraph': "A crane lifts the rocket-powered descent stage away from NASA's Mars 2020 rover after technicians tested the pyrotechnic charges that separate the two spacecraft."}
# {'_id': ObjectId('5e71429200520b92e8cf74e3'), 'date': 'March  5, 2020', 'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover", 'paragraph': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '}
# {'_id': ObjectId('5e71429200520b92e8cf74e4'), 'date': 'March  4, 2020', 'title': "NASA's Curiosity Mars Rover Snaps Its Highest-Resolution Panorama Yet", 'paragraph': 'To go along with the stunning 1.8-billion-pixel image, a new video offers a sweeping view of the Red Planet.'}
# {'_id': ObjectId('5e71429200520b92e8cf74e5'), 'date': 'March  3, 2020', 'title': 'NASA to Reveal Name of Its Next Mars Rover', 'paragraph': "After a months-long contest among students to name NASA's newest Mars rover, the agency will reveal the winning name — and the winning student — this Thursday. "}
# {'_id': ObjectId('5e71429200520b92e8cf74e6'), 'date': 'February 27, 2020', 'title': 'The MarCO Mission Comes to an End', 'paragraph': 'The pair of briefcase-sized satellites made history when they sailed past Mars in 2019.'}
# {'_id': ObjectId('5e71429200520b92e8cf74e7'), 'date': 'February 24, 2020', 'title': "A Year of Surprising Science From NASA's InSight Mars Mission", 'paragraph': "A batch of new papers summarizes the lander's findings above and below the surface of the Red Planet."}
# {'_id': ObjectId('5e71429200520b92e8cf74e8'), 'date': 'February 21, 2020', 'title': "Mars InSight Lander to Push on Top of the 'Mole'", 'paragraph': 'Engineers have a plan for pushing down on the heat probe, which has been stuck at the Martian surface for a year.'}
# {'_id': ObjectId('5e71429200520b92e8cf74e9'), 'date': 'February 21, 2020', 'title': "Common Questions about InSight's 'Mole'", 'paragraph': 'The following Q&As with members of the team answer some of the most common questions about the burrowing device, part of a science instrument called the Heat Flow and Physical Properties Package (HP3).'}
# {'_id': ObjectId('5e71429200520b92e8cf74ea'), 'date': 'February 20, 2020', 'title': 'NASA Adds Return Sample Scientists to Mars 2020 Leadership Team', 'paragraph': 'The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.'}
# {'_id': ObjectId('5e71429200520b92e8cf74eb'), 'date': 'February 18, 2020', 'title': "NASA's Mars Reconnaissance Orbiter Undergoes Memory Update", 'paragraph': 'Other orbiters will continue relaying data from Mars surface missions for a two-week period.'}
# {'_id': ObjectId('5e71429200520b92e8cf74ec'), 'date': 'February 12, 2020', 'title': "NASA's Mars 2020 Rover Goes Coast-to-Coast to Prep for Launch", 'paragraph': "The agency's first step in returning rocks from Mars just arrived at Kennedy Space Center. The Mars 2020 team now begins readying for a launch to the Red Planet this July."}
# {'_id': ObjectId('5e71429200520b92e8cf74ed'), 'date': 'February 11, 2020', 'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network', 'paragraph': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'}
# {'_id': ObjectId('5e71429200520b92e8cf74ee'), 'date': 'February 10, 2020', 'title': 'NASA Administrator Statement on Moon to Mars Initiative, FY 2021 Budget', 'paragraph': "Jim Bridenstine addresses NASA's ambitious plans for the coming years, including Mars Sample Return."}
# {'_id': ObjectId('5e71429200520b92e8cf74ef'), 'date': 'February  7, 2020', 'title': "All About the Laser (and Microphone) Atop Mars 2020, NASA's Next Rover", 'paragraph': 'SuperCam is a rock-vaporizing instrument that will help scientists hunt for Mars fossils.'}
# {'_id': ObjectId('5e71429300520b92e8cf74f0'), 'date': 'February  3, 2020', 'title': "NASA's MAVEN Explores Mars to Understand Radio Interference at Earth", 'paragraph': 'NASA’s MAVEN spacecraft has discovered “layers” and “rifts” in the electrically charged part of the upper atmosphere of Mars.'}
# {'_id': ObjectId('5e71429300520b92e8cf74f1'), 'date': 'January 21, 2020', 'title': "Nine Finalists Chosen in NASA's Mars 2020 Rover Naming Contest", 'paragraph': "Nine finalists have been chosen in the essay contest for K-12 students across U.S. to name NASA's next Mars rover. Now you can help by voting for your favorite. "}
# {'_id': ObjectId('5e71429300520b92e8cf74f2'), 'date': 'January 13, 2020', 'title': "NASA's Mars 2020 Rover Closer to Getting Its Name", 'paragraph': "155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July."}
# {'_id': ObjectId('5e71429300520b92e8cf74f3'), 'date': 'December 27, 2019', 'title': "Media Get a Close-Up of NASA's Mars 2020 Rover", 'paragraph': "The clean room at NASA's Jet Propulsion Laboratory was open to the media to see NASA's next Mars explorer before it leaves for Florida in preparation for a summertime launch."}
# {'_id': ObjectId('5e71429300520b92e8cf74f4'), 'date': 'December 23, 2019', 'title': 'Space History Is Made in This NASA Robot Factory', 'paragraph': "From rockets to rovers, JPL's Spacecraft Assembly Facility has been at the center of robotic spaceflight. Here's a closer look at what makes it so special."}
# {'_id': ObjectId('5e71429300520b92e8cf74f5'), 'date': 'December 18, 2019', 'title': "NASA's Mars 2020 Rover Completes Its First Drive", 'paragraph': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'}
# {'_id': ObjectId('5e71429300520b92e8cf74f6'), 'date': 'December 12, 2019', 'title': "NASA's MAVEN Maps Winds in the Martian Upper Atmosphere that Mirror the Terrain Below and Gives Clues to Martian Climate", 'paragraph': 'Researchers have created the first map of wind circulation in the upper atmosphere of a planet besides Earth, using data from NASA’s MAVEN spacecraft that were collected during the last two years.'}
# {'_id': ObjectId('5e71429300520b92e8cf74f7'), 'date': 'December 12, 2019', 'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate", 'paragraph': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'}
# {'_id': ObjectId('5e71429300520b92e8cf74f8'), 'date': 'December 10, 2019', 'title': "NASA's Treasure Map for Water Ice on Mars", 'paragraph': 'A new study identifies frozen water just below the Martian surface, where astronauts could easily dig it up.'}
# {'_id': ObjectId('5e71429300520b92e8cf74f9'), 'date': 'December 10, 2019', 'title': 'Two Rovers to Roll on Mars Again: Curiosity and Mars 2020', 'paragraph': 'They look like twins. But under the hood, the rover currently exploring the Red Planet and the one launching there this summer have distinct science tools and roles to play.'}
# {'_id': ObjectId('5e71429300520b92e8cf74fa'), 'date': 'November 27, 2019', 'title': "NASA's Briefcase-Size MarCO Satellite Picks Up Honors", 'paragraph': 'The twin spacecraft, the first of their kind to fly into deep space, earn a Laureate from Aviation Week & Space Technology.'}
# {'_id': ObjectId('5e71429300520b92e8cf74fb'), 'date': 'November 26, 2019', 'title': 'Global Storms on Mars Launch Dust Towers Into the Sky', 'paragraph': 'A Mars Dust Tower Stands Out Dust storms are common on Mars. But every decade or so, something unpredictable happens: a series of runaway storms break out, covering the entire planet in a dusty haze.'}
# {'_id': ObjectId('5e71429300520b92e8cf74fc'), 'date': 'November 21, 2019', 'title': 'NASA Updates Mars 2020 Mission Environmental Review', 'paragraph': 'NASA and the Department of Energy have completed a more detailed risk analysis for the Mars 2020 rover launch from Florida.'}
# {'_id': ObjectId('5e71429300520b92e8cf74fd'), 'date': 'November 20, 2019', 'title': 'Two of a Space Kind: Apollo 12 and Mars 2020', 'paragraph': 'Apollo 12 and the upcoming Mars 2020 mission may be separated by half a century, but they share several goals unique in the annals of space exploration.'}
# {'_id': ObjectId('5e71429300520b92e8cf74fe'), 'date': 'November 15, 2019', 'title': 'Mars Scientists Investigate Ancient Life in Australia', 'paragraph': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "}
# {'_id': ObjectId('5e71429300520b92e8cf74ff'), 'date': 'November 12, 2019', 'title': "NASA's Mars 2020 Will Hunt for Microscopic Fossils", 'paragraph': "A new paper identifies a ring of minerals at the rover's landing site that are ideal for fossilizing microbial life."}
# {'_id': ObjectId('5e71429300520b92e8cf7500'), 'date': 'November 12, 2019', 'title': 'With Mars Methane Mystery Unsolved, Curiosity Serves Scientists a New One: Oxygen', 'paragraph': 'For the first time in the history of space exploration, scientists have measured the seasonal changes in the gases that fill the air directly above the surface of Gale Crater on Mars. '}
# {'_id': ObjectId('5e71429300520b92e8cf7501'), 'date': 'November  7, 2019', 'title': "NASA's Mars 2020 Heads Into the Test Chamber", 'paragraph': 'In this time-lapse video taken at JPL, engineers move the Mars 2020 rover into a large vacuum chamber for testing in Mars-like environmental conditions.'}
# {'_id': ObjectId('5e71429300520b92e8cf7502'), 'date': 'November  7, 2019', 'title': "Screening Soon: 'The Pathfinders' Trains Lens on Mars", 'paragraph': 'With the Mars 2020 mission ramping up, the documentary — the first of four about past JPL missions to the Red Planet to be shown at Caltech — tells a gripping backstory.'}
# {'_id': ObjectId('5e71429300520b92e8cf7503'), 'date': 'November  6, 2019', 'title': "InSight's 'Mole' Team Peers into the Pit", 'paragraph': 'Efforts to save the heat probe continue.'}
# {'_id': ObjectId('5e71429300520b92e8cf7504'), 'date': 'October 24, 2019', 'title': 'Mars 2020 Stands on Its Own Six Wheels', 'paragraph': "In time-lapse video, taken at JPL, captures the first time NASA's Mars 2020 rover carries its full weight on its legs and wheels."}
# {'_id': ObjectId('5e71429300520b92e8cf7505'), 'date': 'October 24, 2019', 'title': 'New Selfie Shows Curiosity, the Mars Chemist', 'paragraph': 'The NASA rover performed a special chemistry experiment at the location captured in its newest self-portrait.'}
# {'_id': ObjectId('5e71429300520b92e8cf7506'), 'date': 'October 22, 2019', 'title': 'Naming a NASA Mars Rover Can Change Your Life', 'paragraph': 'Want to name the robotic scientist NASA is sending to Mars in 2020? The student who named Curiosity — the rover currently exploring Mars — will tell you this is an opportunity worth taking.'}
# {'_id': ObjectId('5e71429300520b92e8cf7507'), 'date': 'October 18, 2019', 'title': 'Mars 2020 Unwrapped and Ready for More Testing', 'paragraph': "In time-lapse video, bunny-suited engineers remove the inner layer of protective foil on NASA's Mars 2020 rover after it was relocated for testing."}
# {'_id': ObjectId('5e71429300520b92e8cf7508'), 'date': 'October 16, 2019', 'title': "HiRISE Views NASA's InSight and Curiosity on Mars", 'paragraph': 'New images taken from space offer the clearest orbital glimpse yet of InSight as well as a view of Curiosity rolling along.'}
# {'_id': ObjectId('5e71429300520b92e8cf7509'), 'date': 'October  7, 2019', 'title': "NASA's Curiosity Rover Finds an Ancient Oasis on Mars", 'paragraph': "New evidence suggests salty, shallow ponds once dotted a Martian crater — a sign of the planet's drying climate."}
# {'_id': ObjectId('5e71429300520b92e8cf750a'), 'date': 'October  4, 2019', 'title': "NASA's Mars 2020 Rover Tests Descent-Stage Separation", 'paragraph': "A crane lifts the rocket-powered descent stage away from NASA's Mars 2020 rover after technicians tested the pyrotechnic charges that separate the two spacecraft."}
# {'_id': ObjectId('5e71915fc33afedc8bde73bb'), 'date': 'March  5, 2020', 'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover", 'paragraph': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '}
# {'_id': ObjectId('5e719160c33afedc8bde73bc'), 'date': 'March  4, 2020', 'title': "NASA's Curiosity Mars Rover Snaps Its Highest-Resolution Panorama Yet", 'paragraph': 'To go along with the stunning 1.8-billion-pixel image, a new video offers a sweeping view of the Red Planet.'}
# {'_id': ObjectId('5e719160c33afedc8bde73bd'), 'date': 'March  3, 2020', 'title': 'NASA to Reveal Name of Its Next Mars Rover', 'paragraph': "After a months-long contest among students to name NASA's newest Mars rover, the agency will reveal the winning name — and the winning student — this Thursday. "}
# {'_id': ObjectId('5e719160c33afedc8bde73be'), 'date': 'February 27, 2020', 'title': 'The MarCO Mission Comes to an End', 'paragraph': 'The pair of briefcase-sized satellites made history when they sailed past Mars in 2019.'}
# {'_id': ObjectId('5e719160c33afedc8bde73bf'), 'date': 'February 24, 2020', 'title': "A Year of Surprising Science From NASA's InSight Mars Mission", 'paragraph': "A batch of new papers summarizes the lander's findings above and below the surface of the Red Planet."}
# {'_id': ObjectId('5e719160c33afedc8bde73c0'), 'date': 'February 21, 2020', 'title': "Mars InSight Lander to Push on Top of the 'Mole'", 'paragraph': 'Engineers have a plan for pushing down on the heat probe, which has been stuck at the Martian surface for a year.'}
# {'_id': ObjectId('5e719160c33afedc8bde73c1'), 'date': 'February 21, 2020', 'title': "Common Questions about InSight's 'Mole'", 'paragraph': 'The following Q&As with members of the team answer some of the most common questions about the burrowing device, part of a science instrument called the Heat Flow and Physical Properties Package (HP3).'}
# {'_id': ObjectId('5e719160c33afedc8bde73c2'), 'date': 'February 20, 2020', 'title': 'NASA Adds Return Sample Scientists to Mars 2020 Leadership Team', 'paragraph': 'The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.'}
# {'_id': ObjectId('5e719160c33afedc8bde73c3'), 'date': 'February 18, 2020', 'title': "NASA's Mars Reconnaissance Orbiter Undergoes Memory Update", 'paragraph': 'Other orbiters will continue relaying data from Mars surface missions for a two-week period.'}
# {'_id': ObjectId('5e719160c33afedc8bde73c4'), 'date': 'February 12, 2020', 'title': "NASA's Mars 2020 Rover Goes Coast-to-Coast to Prep for Launch", 'paragraph': "The agency's first step in returning rocks from Mars just arrived at Kennedy Space Center. The Mars 2020 team now begins readying for a launch to the Red Planet this July."}
# {'_id': ObjectId('5e719160c33afedc8bde73c5'), 'date': 'February 11, 2020', 'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network', 'paragraph': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'}
# {'_id': ObjectId('5e719160c33afedc8bde73c6'), 'date': 'February 10, 2020', 'title': 'NASA Administrator Statement on Moon to Mars Initiative, FY 2021 Budget', 'paragraph': "Jim Bridenstine addresses NASA's ambitious plans for the coming years, including Mars Sample Return."}
# {'_id': ObjectId('5e719160c33afedc8bde73c7'), 'date': 'February  7, 2020', 'title': "All About the Laser (and Microphone) Atop Mars 2020, NASA's Next Rover", 'paragraph': 'SuperCam is a rock-vaporizing instrument that will help scientists hunt for Mars fossils.'}
# {'_id': ObjectId('5e719160c33afedc8bde73c8'), 'date': 'February  3, 2020', 'title': "NASA's MAVEN Explores Mars to Understand Radio Interference at Earth", 'paragraph': 'NASA’s MAVEN spacecraft has discovered “layers” and “rifts” in the electrically charged part of the upper atmosphere of Mars.'}
# {'_id': ObjectId('5e719160c33afedc8bde73c9'), 'date': 'January 21, 2020', 'title': "Nine Finalists Chosen in NASA's Mars 2020 Rover Naming Contest", 'paragraph': "Nine finalists have been chosen in the essay contest for K-12 students across U.S. to name NASA's next Mars rover. Now you can help by voting for your favorite. "}
# {'_id': ObjectId('5e719160c33afedc8bde73ca'), 'date': 'January 13, 2020', 'title': "NASA's Mars 2020 Rover Closer to Getting Its Name", 'paragraph': "155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July."}
# {'_id': ObjectId('5e719160c33afedc8bde73cb'), 'date': 'December 27, 2019', 'title': "Media Get a Close-Up of NASA's Mars 2020 Rover", 'paragraph': "The clean room at NASA's Jet Propulsion Laboratory was open to the media to see NASA's next Mars explorer before it leaves for Florida in preparation for a summertime launch."}
# {'_id': ObjectId('5e719160c33afedc8bde73cc'), 'date': 'December 23, 2019', 'title': 'Space History Is Made in This NASA Robot Factory', 'paragraph': "From rockets to rovers, JPL's Spacecraft Assembly Facility has been at the center of robotic spaceflight. Here's a closer look at what makes it so special."}
# {'_id': ObjectId('5e719160c33afedc8bde73cd'), 'date': 'December 18, 2019', 'title': "NASA's Mars 2020 Rover Completes Its First Drive", 'paragraph': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'}
# {'_id': ObjectId('5e719160c33afedc8bde73ce'), 'date': 'December 12, 2019', 'title': "NASA's MAVEN Maps Winds in the Martian Upper Atmosphere that Mirror the Terrain Below and Gives Clues to Martian Climate", 'paragraph': 'Researchers have created the first map of wind circulation in the upper atmosphere of a planet besides Earth, using data from NASA’s MAVEN spacecraft that were collected during the last two years.'}
# {'_id': ObjectId('5e719160c33afedc8bde73cf'), 'date': 'December 12, 2019', 'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate", 'paragraph': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'}
# {'_id': ObjectId('5e719160c33afedc8bde73d0'), 'date': 'December 10, 2019', 'title': "NASA's Treasure Map for Water Ice on Mars", 'paragraph': 'A new study identifies frozen water just below the Martian surface, where astronauts could easily dig it up.'}
# {'_id': ObjectId('5e719160c33afedc8bde73d1'), 'date': 'December 10, 2019', 'title': 'Two Rovers to Roll on Mars Again: Curiosity and Mars 2020', 'paragraph': 'They look like twins. But under the hood, the rover currently exploring the Red Planet and the one launching there this summer have distinct science tools and roles to play.'}
# {'_id': ObjectId('5e719160c33afedc8bde73d2'), 'date': 'November 27, 2019', 'title': "NASA's Briefcase-Size MarCO Satellite Picks Up Honors", 'paragraph': 'The twin spacecraft, the first of their kind to fly into deep space, earn a Laureate from Aviation Week & Space Technology.'}
# {'_id': ObjectId('5e719160c33afedc8bde73d3'), 'date': 'November 26, 2019', 'title': 'Global Storms on Mars Launch Dust Towers Into the Sky', 'paragraph': 'A Mars Dust Tower Stands Out Dust storms are common on Mars. But every decade or so, something unpredictable happens: a series of runaway storms break out, covering the entire planet in a dusty haze.'}
# {'_id': ObjectId('5e719160c33afedc8bde73d4'), 'date': 'November 21, 2019', 'title': 'NASA Updates Mars 2020 Mission Environmental Review', 'paragraph': 'NASA and the Department of Energy have completed a more detailed risk analysis for the Mars 2020 rover launch from Florida.'}
# {'_id': ObjectId('5e719160c33afedc8bde73d5'), 'date': 'November 20, 2019', 'title': 'Two of a Space Kind: Apollo 12 and Mars 2020', 'paragraph': 'Apollo 12 and the upcoming Mars 2020 mission may be separated by half a century, but they share several goals unique in the annals of space exploration.'}
# {'_id': ObjectId('5e719160c33afedc8bde73d6'), 'date': 'November 15, 2019', 'title': 'Mars Scientists Investigate Ancient Life in Australia', 'paragraph': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "}
# {'_id': ObjectId('5e719160c33afedc8bde73d7'), 'date': 'November 12, 2019', 'title': "NASA's Mars 2020 Will Hunt for Microscopic Fossils", 'paragraph': "A new paper identifies a ring of minerals at the rover's landing site that are ideal for fossilizing microbial life."}
# {'_id': ObjectId('5e719160c33afedc8bde73d8'), 'date': 'November 12, 2019', 'title': 'With Mars Methane Mystery Unsolved, Curiosity Serves Scientists a New One: Oxygen', 'paragraph': 'For the first time in the history of space exploration, scientists have measured the seasonal changes in the gases that fill the air directly above the surface of Gale Crater on Mars. '}
# {'_id': ObjectId('5e719160c33afedc8bde73d9'), 'date': 'November  7, 2019', 'title': "NASA's Mars 2020 Heads Into the Test Chamber", 'paragraph': 'In this time-lapse video taken at JPL, engineers move the Mars 2020 rover into a large vacuum chamber for testing in Mars-like environmental conditions.'}
# {'_id': ObjectId('5e719160c33afedc8bde73da'), 'date': 'November  7, 2019', 'title': "Screening Soon: 'The Pathfinders' Trains Lens on Mars", 'paragraph': 'With the Mars 2020 mission ramping up, the documentary — the first of four about past JPL missions to the Red Planet to be shown at Caltech — tells a gripping backstory.'}
# {'_id': ObjectId('5e719160c33afedc8bde73db'), 'date': 'November  6, 2019', 'title': "InSight's 'Mole' Team Peers into the Pit", 'paragraph': 'Efforts to save the heat probe continue.'}
# {'_id': ObjectId('5e719160c33afedc8bde73dc'), 'date': 'October 24, 2019', 'title': 'Mars 2020 Stands on Its Own Six Wheels', 'paragraph': "In time-lapse video, taken at JPL, captures the first time NASA's Mars 2020 rover carries its full weight on its legs and wheels."}
# {'_id': ObjectId('5e719160c33afedc8bde73dd'), 'date': 'October 24, 2019', 'title': 'New Selfie Shows Curiosity, the Mars Chemist', 'paragraph': 'The NASA rover performed a special chemistry experiment at the location captured in its newest self-portrait.'}
# {'_id': ObjectId('5e719160c33afedc8bde73de'), 'date': 'October 22, 2019', 'title': 'Naming a NASA Mars Rover Can Change Your Life', 'paragraph': 'Want to name the robotic scientist NASA is sending to Mars in 2020? The student who named Curiosity — the rover currently exploring Mars — will tell you this is an opportunity worth taking.'}
# {'_id': ObjectId('5e719160c33afedc8bde73df'), 'date': 'October 18, 2019', 'title': 'Mars 2020 Unwrapped and Ready for More Testing', 'paragraph': "In time-lapse video, bunny-suited engineers remove the inner layer of protective foil on NASA's Mars 2020 rover after it was relocated for testing."}
# {'_id': ObjectId('5e719160c33afedc8bde73e0'), 'date': 'October 16, 2019', 'title': "HiRISE Views NASA's InSight and Curiosity on Mars", 'paragraph': 'New images taken from space offer the clearest orbital glimpse yet of InSight as well as a view of Curiosity rolling along.'}
# {'_id': ObjectId('5e719160c33afedc8bde73e1'), 'date': 'October  7, 2019', 'title': "NASA's Curiosity Rover Finds an Ancient Oasis on Mars", 'paragraph': "New evidence suggests salty, shallow ponds once dotted a Martian crater — a sign of the planet's drying climate."}
# {'_id': ObjectId('5e719160c33afedc8bde73e2'), 'date': 'October  4, 2019', 'title': "NASA's Mars 2020 Rover Tests Descent-Stage Separation", 'paragraph': "A crane lifts the rocket-powered descent stage away from NASA's Mars 2020 rover after technicians tested the pyrotechnic charges that separate the two spacecraft."}

# %%
# How can I expor this mongo collecto to CSV? (Not required for homework, but I'm interested in how to do it)
# Export MongoDB collection
#mongoexport --db nasaNews_db --collection items --type=csv --fields _id,date,title,paragraph --out "nasaNews.csv"

# %% [markdown]
# # JPL Mars Space Images - Featured Image

# %%
# Visit the url for JPL Featured Space Image to be scraped
url_mars_images = "https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars"

# executable path and browser
executable_path = {"executable_path": "/usr/local/bin/chromedriver"}
browser = Browser("chrome", **executable_path, headless=False)

# Scrape site
browser.visit(url_mars_images)

# Create Beatifulsoup object; pase with 'html.parser' or 'lxml'
soup = bs(browser.html, 'html.parser')

# %%
# Image source
mars_image_source = soup.find(class_ = 'carousel_item')['style']

# %%
print(mars_image_source)
# Out:
# background-image: url('/spaceimages/images/wallpaper/PIA18058-1920x1200.jpg');

# %%
# I need to split the string on the url only
image_string = mars_image_source.split("'")[1]
print(image_string)
# Out:
# /spaceimages/images/wallpaper/PIA18058-1920x1200.jpg

# %%
# Featured Mars Image and assign the url string to a variable called featured_image_url.
# I need the base url
base_url = "https://jpl.nasa.gov"

# the string URL I got in the previous step. I'll use the variable named 
# indicated in the homework's instructions. 
featured_image_url = base_url + image_string

# Make sure to save a complete url string for this image.
print(featured_image_url)
# Out:
# https://jpl.nasa.gov/spaceimages/images/wallpaper/PIA18058-1920x1200.jpg

# %%
# How can I save this image? (Not required for homework, but I'm interested in how to do it)
#feature_image_url.save_as.jpg

# %% [markdown]
# # Mars Facts

# %%
# Visit the Mars Facts webpage 
url_mars_facts = 'https://space-facts.com/mars/'
#executable_path = {"executable_path": "/usr/local/bin/chromedriver"}
#browser = Browser("chrome", **executable_path, headless=False)
#browser.visit(url_mars_facts)
#soup = bs(browser.html, 'html.parser')

# %%
#Use Pandas to scrape the table containing facts about the planet including Diameter, Mass, etc.
#to scrape using pandas and nothing else, I have to use the following. Please note that
# the [1] was added b/c the table has two elements and without it, it marked an error
mars_table_df = pd.read_html(url_mars_facts)[1] 
mars_table_df.columns = ['', 'Value']
mars_table_df
# Out:
#                                                  Value
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:            2 (Phobos & Deimos)
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers

# %%
# Use Pandas to convert the data to a HTML table string.
mars_table_string = pd.DataFrame(mars_table_df)
print(mars_table_string.to_string())
# Out:
#                                                  Value
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:            2 (Phobos & Deimos)
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers

# %% [markdown]
# # Mars Hemispheres

# %%
# Visit the USGS Astrogeology site here to obtain high 
# resolution images for each of Mar's hemispheres.
# Visit the url for JPL Featured Space Image to be scraped
url_mars_hemispheres_base = 'https://astrogeology.usgs.gov' 
url_mars_hemispheres_complete = url_mars_hemispheres_base + "/search/results?q=hemisphere+enhanced&k1=target&v1=Mars"
executable_path = {"executable_path": "/usr/local/bin/chromedriver"}
browser = Browser("chrome", **executable_path, headless=False)
browser.visit(url_mars_hemispheres_complete)
soup = bs(browser.html, 'html.parser')
#print(soup.prettify())

# %%
# Create a list to hold the urls
hemisphere_image_urls = []

# You will need to click each of the links to the hemispheres in order to find the image url 
# to the full resolution image.
# Find step by step and append each time to the list.
hemi_first_step = soup.find('div', id='product-section')
hemi_second_step = hemi_first_step.find_all('div', class_='item')
for item in hemi_second_step:
    # Save the Hemisphere title containing the hemisphere name. 
    title = item.find('h3').text 
    new_link = item.find('a')['href']
    browser.visit(url_mars_hemispheres_base + new_link)
    soup = bs(browser.html, 'html.parser')
    downloads = soup.find('div', class_='downloads')
    # Save both the image url string for the full resolution hemisphere image,
    url = downloads.find('a')['href'] 
    # Use a Python dictionary to store the data using the keys img_url and title.
    #Append the dictionary with the image url string and the hemisphere title to a list.
    hemisphere_image_urls.append({'img_url': url, 'title': title})

# This list will contain one dictionary for each hemisphere.
# Print the list
hemisphere_image_urls
# Out:
# [{'img_url': 'http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/cerberus_enhanced.tif/full.jpg',
#   'title': 'Cerberus Hemisphere Enhanced'},
#  {'img_url': 'http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/schiaparelli_enhanced.tif/full.jpg',
#   'title': 'Schiaparelli Hemisphere Enhanced'},
#  {'img_url': 'http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/syrtis_major_enhanced.tif/full.jpg',
#   'title': 'Syrtis Major Hemisphere Enhanced'},
#  {'img_url': 'http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/valles_marineris_enhanced.tif/full.jpg',
#   'title': 'Valles Marineris Hemisphere Enhanced'}]

# %% [markdown]
# # Mars Weather

# %%
# Visit and scrape the Mars Weather twitter account. Find the latest Mars weather tweets from the page. 
url_marsTwitter = "https://twitter.com/marswxreport?lang=en"
#executable_path = {"executable_path": "/usr/local/bin/chromedriver"}
#browser = Browser("chrome", **executable_path, headless=False)
browser.visit(url_marsTwitter)
#twitter_soup = bs(browser.html, 'html.parser')
#print(twitter_soup.prettify())

# %%
#SCRAP to get the requested info
#weather_results = twitter_soup.body.div.div.div.main.div.div.div.div.div.div.div
#print(weather_results)
#print(mars_weather[3])

# class is "TweetTextSize"
# using Splinter within a list comprehension to strip the tweet down to its text; we want the top 
# tweet, so that's index 0
#mars_weather = [tweet.text.strip() for tweet in soup.find_by_css(".TweetTextSize")]
#tweet = soup('span',class_="css-901oao css-16my406 r-1qd0xha r-ad9z0x r-bcqeeo r-qvutc0").text 



#tweet = soup.find("#react-root > div > div > div.css-1dbjc4n.r-1pi2tsx.r-13qz1uu.r-417010 > main > div > div > div > div > div > div > div > div > div:nth-child(3) > section > div > div > div > div:nth-child(4) > div > article > div > div > div:nth-child(2) > div.css-1dbjc4n.r-1iusvr4.r-16y2uox.r-1777fci.r-5f2r5o.r-1mi0q7o > div:nth-child(2) > div:nth-child(1) > div > span")
# Printing results
#print(tweet)

# Save the tweet text for the weather report as a variable called mars_weather.
# Change browser to twitter

#mars_weather = [tweet.text.strip() for tweet in soup.find_by_css(".TweetTextSize")]

#mars_weather = [tweet['@MarsWxReport'] for tweet in soup if tweet['@MarsWxReport'][0]]

# %% [markdown]
# # Step 2 - MongoDB and Flask Application

# %%
# Use MongoDB with Flask templating to create a new HTML page that displays all of the information 
# that was scraped from the URLs above.
# Start by converting your Jupyter notebook into a Python script called scrape_mars.py 
# with a function called scrape that will execute all of your scraping code from above 
# and return one Python dictionary containing all of the scraped data.
# Next, create a route called /scrape that will import your scrape_mars.py script 
# and call your scrape function.
# Store the return value in Mongo as a Python dictionary.
# Create a root route / that will query your Mongo database and pass the mars data into an HTML 
# template to display the data.
# Create a template HTML file called index.html 
# that will take the mars data dictionary and display all of the data in the 
# appropriate HTML elements. 
# Use the following as a guide for what the final product should look like, 
# but feel free to create your own design.
